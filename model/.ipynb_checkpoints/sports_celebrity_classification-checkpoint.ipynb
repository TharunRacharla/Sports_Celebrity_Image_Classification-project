# %% [markdown]
# <h2 style='color:blue' align='center'>Sports Celebrity Image Classification<h2>

# %% [markdown]
# Special thanks to Debjyoti Paul (My data scientist friend at Amazon) for help with this project

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread('E:\Programming\Data Science\imagerecognition\model\dataset\maria_sharapova\maria-sharapova-green-eyes-tennis-player-face.jpg')
img.shape
# Out:
# (1080, 1920, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1080, 1920)

# %%
gray
# Out:
# array([[253, 253, 253, ..., 255, 255, 255],
#        [253, 253, 253, ..., 255, 255, 255],
#        [253, 253, 253, ..., 255, 255, 255],
#        ...,
#        [ 25,  24,  24, ..., 236, 236, 235],
#        [ 22,  23,  23, ..., 233, 232, 232],
#        [ 21,  21,  22, ..., 230, 230, 229]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('E:\Programming\Data Science\imagerecognition\model\opencv\haarcascades\haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('E:\Programming\Data Science\imagerecognition\model\opencv\haarcascades\haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[575, 173, 783, 783]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (575, 173, 783, 783)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (783, 783, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('maria-sharapova-green-eyes-tennis-player-face.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('maria-sharapova-green-eyes-tennis-player-face.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('sharapova2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('sharapova2.jpg')
cropped_image_no_2_eyes

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "E:\Programming\Data Science\imagerecognition\model\dataset"
path_to_cr_data = "E:\Programming\Data Science\imagerecognition\model\dataset\cropped"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\cropped',
#  'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\lionel_messi',
#  'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\maria_sharapova',
#  'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\roger_federer',
#  'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\serena_williams',
#  'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\virat_kohli']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split("\\")[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "\\" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  E:\Programming\Data Science\imagerecognition\model\dataset\croppedlionel_messi
# Generating cropped images in folder:  E:\Programming\Data Science\imagerecognition\model\dataset\croppedmaria_sharapova
# Generating cropped images in folder:  E:\Programming\Data Science\imagerecognition\model\dataset\croppedroger_federer
# Generating cropped images in folder:  E:\Programming\Data Science\imagerecognition\model\dataset\croppedserena_williams
# Generating cropped images in folder:  E:\Programming\Data Science\imagerecognition\model\dataset\croppedvirat_kohli

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('\\')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'croppedlionel_messi': ['E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi1.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi10.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi11.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi12.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi13.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi14.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi15.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi16.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi17.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi18.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi19.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi2.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi20.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi21.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi22.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi23.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi24.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi25.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi26.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi27.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi28.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi29.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi3.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi30.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi31.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi32.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi33.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi34.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi35.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi36.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi37.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi38.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi39.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi4.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi40.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi41.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi42.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi43.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi44.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi45.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi5.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi6.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi7.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi8.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedlionel_messi\\lionel_messi9.png'],
#  'croppedmaria_sharapova': ['E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova1.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova10.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova11.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova12.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova13.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova14.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova15.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova16.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova17.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova18.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova19.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova2.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova20.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova21.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova22.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova23.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova24.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova25.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova26.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova27.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova28.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova29.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova3.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova30.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova31.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova32.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova33.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova34.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova35.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova4.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova5.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova6.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova7.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova8.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedmaria_sharapova\\maria_sharapova9.png'],
#  'croppedroger_federer': ['E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer1.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer10.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer11.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer12.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer13.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer14.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer15.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer16.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer17.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer18.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer19.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer2.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer20.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer21.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer22.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer23.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer24.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer25.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer26.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer27.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer28.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer29.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer3.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer30.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer4.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer5.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer6.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer7.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer8.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedroger_federer\\roger_federer9.png'],
#  'croppedserena_williams': ['E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams1.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams10.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams11.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams12.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams13.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams14.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams15.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams16.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams17.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams18.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams19.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams2.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams20.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams21.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams22.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams23.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams24.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams25.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams26.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams27.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams28.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams29.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams3.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams30.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams31.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams32.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams33.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams34.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams4.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams5.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams6.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams7.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams8.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedserena_williams\\serena_williams9.png'],
#  'croppedvirat_kohli': ['E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli1.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli10.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli11.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli12.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli13.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli14.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli15.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli16.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli17.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli18.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli19.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli2.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli20.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli21.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli22.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli23.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli24.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli25.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli26.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli27.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli28.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli29.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli3.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli30.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli31.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli32.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli33.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli34.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli35.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli36.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli37.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli38.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli39.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli4.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli40.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli41.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli42.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli43.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli44.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli45.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli46.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli47.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli48.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli5.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli6.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli7.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli8.png',
#   'E:\\Programming\\Data Science\\imagerecognition\\model\\dataset\\croppedvirat_kohli\\virat_kohli9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'croppedlionel_messi': 0,
#  'croppedmaria_sharapova': 1,
#  'croppedroger_federer': 2,
#  'croppedserena_williams': 3,
#  'croppedvirat_kohli': 4}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[100],
#        [129],
#        [140],
#        ...,
#        [237],
#        [234],
#        [232]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (192, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7291666666666666

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.73      0.84        11
#            1       0.67      0.75      0.71         8
#            2       0.75      0.60      0.67         5
#            3       0.56      0.56      0.56         9
#            4       0.72      0.87      0.79        15
#
#     accuracy                           0.73        48
#    macro avg       0.74      0.70      0.71        48
# weighted avg       0.75      0.73      0.73        48

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.776847
# 1        random_forest    0.659606
# 2  logistic_regression    0.797783
#
#                                     best_params
# 0          {'svc__C': 10, 'svc__kernel': 'rbf'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc', SVC(C=10, gamma='auto', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7291666666666666

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.6458333333333334

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8125

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 8,  0,  1,  1,  1],
#        [ 0,  6,  0,  1,  1],
#        [ 0,  0,  3,  1,  1],
#        [ 0,  2,  0,  5,  2],
#        [ 0,  1,  0,  1, 13]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'croppedlionel_messi': 0,
#  'croppedmaria_sharapova': 1,
#  'croppedroger_federer': 2,
#  'croppedserena_williams': 3,
#  'croppedvirat_kohli': 4}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Collecting joblib
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      -------------------------------------- 298.0/298.0 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: joblib
# Successfully installed joblib-1.2.0
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
